# %% [markdown]
# # WEATHER DATA
# This notebook contains code used to scrape Visual Crossing Weather API.
# It reads events.csv file with data about each running event, from which date and city are then used as input into the URL.
# From the weather API, several parameters are extracted, presented as a data frame and written to a weather.csv file.

# %%
## Load libraries
library(tidyverse)
library(glue)
library(httr)
library(jsonlite)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.0      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten

# %%
## read the events.csv file
races <- read.csv("events.csv", header=TRUE)

# %%
races
# Out:
#    X  Event                            Link
# 1   1 Tauranga Marathon                https://taurangamarathon.nz
# 2   2 Devonport Half Marathon          https://devonporthalfmarathon.co.nz
# 3   3 Run Orewa                        https://runorewa.nz
# 4   4 Corporate Challenge Wellington   https://corporatechallenge.co.nz
# 5   5 Corporate Challenge Christchurch https://corporatechallenge.co.nz
# 6   6 Corporate Challenge Auckland     https://corporatechallenge.co.nz
# 7   7 Run The Point                    https://runthepoint.nz
# 8   8 Omaha Half Marathon              https://omahahalfmarathon.co.nz
# 9   9 Run Devonport                    https://rundevonport.nz
# 10 10 Coatesville Half Marathon        https://coatesvillehalfmarathon.co.nz
# 11 11 Maraetai Half Marathon           https://maraetaihalfmarathon.co.nz
# 12 12 Run Albany                       https://runalbany.nz
# 13 13 Waterfront Half Marathon         https://waterfronthalfmarathon.co.nz
#    Date       Participants Location     City
# 1  2022-09-18 1570         Tauranga     Tauranga
# 2  2022-10-02 1268         Devonport    Auckland
# 3  2022-10-16  857         Orewa        Auckland
# 4  2020-11-11  393         Wellington   Wellington
# 5  2022-02-16  767         Christchurch Christchurch
# 6  2020-11-18  938         Auckland     Auckland
# 7  2022-02-20  771         Hobsonville  Auckland
# 8  2022-03-27 1689         Omaha        Auckland
# 9  2022-02-07  768         Devonport    Auckland
# 10 2022-02-13 1270         Coatesville  Auckland
# 11 2022-03-13 1359         Maraetai     Auckland
# 12 2022-03-20  792         Albany       Auckland
# 13 2022-04-10 2147         Auckland     Auckland

# %%
##run function to obtain weather data

get_weather <- function(races) {
    weather = NULL
    for(i in 1:nrow(races)) {
        city = races$City # assign variable to City column in races data frame
        date = races$Date # assign variable to Date column in races dataframe
        query_url <- glue("https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{city[i]}/{date[i]}/{date[i]}?unitGroup=metric&key=2AGY57Q48GAUKNU3LA8E2YAYC&contentType=json")
        api_call <- httr::GET(query_url, encoding = "json")
        api_content <- api_call$content
        api_char <- rawToChar(api_content)
        api_json <- jsonlite::stream_in(textConnection(api_char), simplifyDataFrame = FALSE)
        Date <- api_json[[1]][['days']][[1]][['datetime']] # extract date 
        Condition <- api_json[[1]][['days']][[1]][['conditions']] # extract condition description
        Temp <- api_json[[1]][['days']][[1]][['temp']] # extract average temperature
        Rain <- api_json[[1]][['days']][[1]][['precip']] # extract amount of rain
        Wind <- api_json[[1]][['days']][[1]][['windspeed']] # extract wind speed
        Pressure <- api_json[[1]][['days']][[1]][['pressure']] # extract pressure
        Visibility <- api_json[[1]][['days']][[1]][['visibility']] # extract visibility
        Cloud <- api_json[[1]][['days']][[1]][['cloudcover']] # extract cloud cover
        UV <- api_json[[1]][['days']][[1]][['uvindex']] # extract UV index
        weather = rbind(weather, data.frame(Date, Condition, Temp, Rain, Wind, Pressure, Visibility, Cloud, UV)) }
                        
    print(weather) }

# %%
weather <- get_weather(races)
# Out:
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#  Imported 1 records. Simplifying...
#          Date              Condition Temp  Rain Wind Pressure Visibility Cloud
# 1  2022-09-18                  Clear 11.6  0.00 14.8   1027.1       20.0   0.0
# 2  2022-10-02 Rain, Partially cloudy 16.5  3.99 24.7   1001.3       11.6  49.7
# 3  2022-10-16 Rain, Partially cloudy 14.0  0.10 29.5   1013.7       10.6  26.3
# 4  2020-11-11 Rain, Partially cloudy 12.0  0.03 39.3   1015.5       10.6  81.5
# 5  2022-02-16       Partially cloudy 16.9  0.00 27.6   1018.2       11.5  38.9
# 6  2020-11-18 Rain, Partially cloudy 17.4  0.77 42.6   1010.5       12.6  29.9
# 7  2022-02-20                  Clear 21.1  0.00 22.0   1016.2       13.5  16.5
# 8  2022-03-27                  Clear 17.5  0.00 20.5   1016.1       13.7   3.0
# 9  2022-02-07 Rain, Partially cloudy 20.8 46.31 22.0   1010.7       10.2  60.5
# 10 2022-02-13 Rain, Partially cloudy 20.9  3.21 76.0   1000.1        9.9  48.3
# 11 2022-03-13       Partially cloudy 22.3  0.00 20.2   1019.1       13.1  40.9
# 12 2022-03-20 Rain, Partially cloudy 20.0  0.23 44.6   1012.2       13.2  47.7
# 13 2022-04-10                  Clear 16.9  0.00 16.6   1027.4       13.3   0.0
#    UV
# 1   6
# 2   7
# 3  10
# 4   4
# 5   9
# 6  10
# 7   8
# 8   7
# 9   3
# 10  8
# 11  9
# 12  4
# 13  8

# %%
weather
# Out:
#    Date       Condition              Temp Rain  Wind Pressure Visibility Cloud
# 1  2022-09-18 Clear                  11.6  0.00 14.8 1027.1   20.0        0.0
# 2  2022-10-02 Rain, Partially cloudy 16.5  3.99 24.7 1001.3   11.6       49.7
# 3  2022-10-16 Rain, Partially cloudy 14.0  0.10 29.5 1013.7   10.6       26.3
# 4  2020-11-11 Rain, Partially cloudy 12.0  0.03 39.3 1015.5   10.6       81.5
# 5  2022-02-16 Partially cloudy       16.9  0.00 27.6 1018.2   11.5       38.9
# 6  2020-11-18 Rain, Partially cloudy 17.4  0.77 42.6 1010.5   12.6       29.9
# 7  2022-02-20 Clear                  21.1  0.00 22.0 1016.2   13.5       16.5
# 8  2022-03-27 Clear                  17.5  0.00 20.5 1016.1   13.7        3.0
# 9  2022-02-07 Rain, Partially cloudy 20.8 46.31 22.0 1010.7   10.2       60.5
# 10 2022-02-13 Rain, Partially cloudy 20.9  3.21 76.0 1000.1    9.9       48.3
# 11 2022-03-13 Partially cloudy       22.3  0.00 20.2 1019.1   13.1       40.9
# 12 2022-03-20 Rain, Partially cloudy 20.0  0.23 44.6 1012.2   13.2       47.7
# 13 2022-04-10 Clear                  16.9  0.00 16.6 1027.4   13.3        0.0
#    UV
# 1   6
# 2   7
# 3  10
# 4   4
# 5   9
# 6  10
# 7   8
# 8   7
# 9   3
# 10  8
# 11  9
# 12  4
# 13  8

# %%
##Rename columns
weather <- weather %>%
  rename('Average Temp' = Temp,
        Precipitation = Rain,
        'Cloud Cover' = Cloud)

# %%
weather
# Out:
#    Date       Condition              Average Temp Precipitation Wind Pressure
# 1  2022-09-18 Clear                  11.6          0.00         14.8 1027.1
# 2  2022-10-02 Rain, Partially cloudy 16.5          3.99         24.7 1001.3
# 3  2022-10-16 Rain, Partially cloudy 14.0          0.10         29.5 1013.7
# 4  2020-11-11 Rain, Partially cloudy 12.0          0.03         39.3 1015.5
# 5  2022-02-16 Partially cloudy       16.9          0.00         27.6 1018.2
# 6  2020-11-18 Rain, Partially cloudy 17.4          0.77         42.6 1010.5
# 7  2022-02-20 Clear                  21.1          0.00         22.0 1016.2
# 8  2022-03-27 Clear                  17.5          0.00         20.5 1016.1
# 9  2022-02-07 Rain, Partially cloudy 20.8         46.31         22.0 1010.7
# 10 2022-02-13 Rain, Partially cloudy 20.9          3.21         76.0 1000.1
# 11 2022-03-13 Partially cloudy       22.3          0.00         20.2 1019.1
# 12 2022-03-20 Rain, Partially cloudy 20.0          0.23         44.6 1012.2
# 13 2022-04-10 Clear                  16.9          0.00         16.6 1027.4
#    Visibility Cloud Cover UV
# 1  20.0        0.0         6
# 2  11.6       49.7         7
# 3  10.6       26.3        10
# 4  10.6       81.5         4
# 5  11.5       38.9         9
# 6  12.6       29.9        10
# 7  13.5       16.5         8
# 8  13.7        3.0         7
# 9  10.2       60.5         3
# 10  9.9       48.3         8
# 11 13.1       40.9         9
# 12 13.2       47.7         4
# 13 13.3        0.0         8

# %%
## Save as CSV file 
write.csv(weather,"weather.csv")
