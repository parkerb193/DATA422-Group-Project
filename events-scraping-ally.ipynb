# %%
# Libraries
library(xml2)
library(rvest)
library(tidyverse)
library(magrittr)
library(purrr)
library(glue)
library(stringr)
library(tidytext)
library(textdata)
library(dplyr)
library(httr)
library(jsonlite)
# Out:
# ── Attaching packages ─────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter()         masks stats::filter()
# ✖ readr::guess_encoding() masks rvest::guess_encoding()
# ✖ dplyr::lag()            masks stats::lag()
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:purrr':
#
#     set_names
#
#
# The following object is masked from 'package:tidyr':
#
#     extract
#
#
#
# Attaching package: 'httr'
#
#
# The following object is masked from 'package:textdata':
#
#     cache_info
#
#
#
# Attaching package: 'jsonlite'
#
#
# The following object is masked from 'package:purrr':
#
#     flatten

# %%
## Scrape running events page 
# URL for base page 
url <- "https://runningevents.co.nz/#events"
# Base page HTML
events_html <- read_html(url)
# Event name 
event_name <- events_html %>%
    html_nodes('.mb-3 .position-relative h5') %>%
    html_text()
# Event date 
event_date <- events_html %>%
    html_nodes('.mb-3 .position-relative p') %>%
    html_text()
# Event link
event_link <- events_html %>%
    html_nodes('a.mt-2') %>% 
    html_attrs() %>% 
    map_chr("href")
# Dataframe 
event_link_df <- data.frame(Event = event_name, Date = event_date, Link = event_link)
# Remove date column
event_link_df <- event_link_df[-2]
# Show results
event_link_df
# Out:
#    Event                            Link
# 1  Tauranga Marathon                https://taurangamarathon.nz
# 2  Devonport Half Marathon          https://devonporthalfmarathon.co.nz
# 3  Run Orewa                        https://runorewa.nz
# 4  Corporate Challenge Wellington   https://corporatechallenge.co.nz
# 5  Corporate Challenge Christchurch https://corporatechallenge.co.nz
# 6  Corporate Challenge Auckland     https://corporatechallenge.co.nz
# 7  Run The Point                    https://runthepoint.nz
# 8  Omaha Half Marathon              https://omahahalfmarathon.co.nz
# 9  Run Devonport                    https://rundevonport.nz
# 10 Coatesville Half Marathon        https://coatesvillehalfmarathon.co.nz
# 11 Maraetai Half Marathon           https://maraetaihalfmarathon.co.nz
# 12 Run Albany                       https://runalbany.nz
# 13 Waterfront Half Marathon         https://waterfronthalfmarathon.co.nz

# %%
## Scrape running events page further detail
# URL for base page 
url <- "https://results.runningevents.co.nz/Home"
# Base page HTML
runningevents_html <- read_html(url)
# Event table 
event_table <- runningevents_html %>%
    html_nodes('#data-table-results') %>%
    html_table()
event_df <- event_table[[1]]

## Tidy data 
# Remove empty column
event_df <- event_df[-5]
event_df <- event_df[-3]
# Remove date from 
event_df$Event <- gsub('[0-9]+', '', event_df$Event)

## City
# Locations and corresponding cities 
location_list <- list(
    "Rotorua" = c("Rotorua"),
    "Auckland" = c("Auckland", "Devonport", "Coatesville", "Albany", "Orewa", "Omaha", "Maraetai", "run the point", "waterfront"), 
    "Christchurch" = c("Christchurch"), 
    "Tauranga" = c("Tauranga"), 
    "Wellington" = c("Wellington"), 
    "Virtual" = c("Virtual"))
# Names of cities
cities <- names(location_list)
# Creating empty columns in events df
event_df$Location <- NA
event_df$City <- NA
# Fill in city and location results
for (city in cities) {
    for (location in location_list[[city]]) {
        matches <- grep(location, event_df$Event, ignore.case = TRUE) # if location matches regular expression
        event_df[matches, "City"]  = city # populate cell of df with city
        if (location == 'run the point') {
            location <- 'Hobsonville'}
        if (location == 'waterfront') {
            location <- 'Auckland'}
        event_df[matches, "Location"]  = location # populate cell of df with location
    }}

## Recent events 
# Convert date to datetime
event_df$Date <- as.POSIXct(event_df$Date, format = "%d/%m/%Y")
# Remove all but most recent occurance 
event_df <-  event_df %>% 
    group_by(Event) %>% 
    filter(Date == max(Date))

# Show results
event_df %>%
    head()
# Out:
#   Date       Event                                             Participants
# 1 2011-11-02  Corporate Challenge - Christchurch                427
# 2 2011-11-16  Corporate Challenge - Wellington                  546
# 3 2011-11-23  Corporate Challenge - Auckland                   1120
# 4 2012-11-07  Fidelity Life Corporate Challenge - Christchurch  375
# 5 2012-11-14  Fidelity Life Corporate Challenge - Wellington    289
# 6 2012-11-21  Fidelity Life Corporate Challenge - Auckland      795
#   Location     City
# 1 Christchurch Christchurch
# 2 Wellington   Wellington
# 3 Auckland     Auckland
# 4 Christchurch Christchurch
# 5 Wellington   Wellington
# 6 Auckland     Auckland

# %%
## Combine tables 
# Join tables
event_df$Event <- trimws(event_df$Event)
event_df <- left_join(event_link_df, event_df, by = 'Event')

# Show results
event_df
# Out:
#    Event                            Link
# 1  Tauranga Marathon                https://taurangamarathon.nz
# 2  Devonport Half Marathon          https://devonporthalfmarathon.co.nz
# 3  Run Orewa                        https://runorewa.nz
# 4  Corporate Challenge Wellington   https://corporatechallenge.co.nz
# 5  Corporate Challenge Christchurch https://corporatechallenge.co.nz
# 6  Corporate Challenge Auckland     https://corporatechallenge.co.nz
# 7  Run The Point                    https://runthepoint.nz
# 8  Omaha Half Marathon              https://omahahalfmarathon.co.nz
# 9  Run Devonport                    https://rundevonport.nz
# 10 Coatesville Half Marathon        https://coatesvillehalfmarathon.co.nz
# 11 Maraetai Half Marathon           https://maraetaihalfmarathon.co.nz
# 12 Run Albany                       https://runalbany.nz
# 13 Waterfront Half Marathon         https://waterfronthalfmarathon.co.nz
#    Date       Participants Location     City
# 1  2022-09-18 1570         Tauranga     Tauranga
# 2  2022-10-02 1268         Devonport    Auckland
# 3  2022-10-16  834         Orewa        Auckland
# 4  2020-11-11  393         Wellington   Wellington
# 5  2022-02-16  767         Christchurch Christchurch
# 6  2020-11-18  938         Auckland     Auckland
# 7  2022-02-20  771         Hobsonville  Auckland
# 8  2022-03-27 1689         Omaha        Auckland
# 9  2022-02-07  768         Devonport    Auckland
# 10 2022-02-13 1270         Coatesville  Auckland
# 11 2022-03-13 1359         Maraetai     Auckland
# 12 2022-03-20  792         Albany       Auckland
# 13 2022-04-10 2147         Auckland     Auckland

# %%
## Save as CSV file 
write.csv(event_df,"events.csv")
